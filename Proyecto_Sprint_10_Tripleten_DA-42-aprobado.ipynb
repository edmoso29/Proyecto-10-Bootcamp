# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Proyecto de Sprint 10

# %% [markdown]
# ## Priorización de Hipótesis y Análisis de Pruebas A/B para una Tienda Online

# %% [markdown]
# ## Parte 1; Priorización de Hipótesis

# %% [markdown]
# ### 1.1 - Importación de librerías, carga y visualización de datos

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import math as mth
from math import factorial
from scipy import stats as st

# %%
hipotesis = pd.read_csv('/datasets/hypotheses_us.csv', sep = ';')
hipotesis.info()
print()
hipotesis.head(9)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Effort      9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
#                                           Hypothesis  Reach  Impact  \
# 0  Add two new channels for attracting traffic. T...      3      10
# 1  Launch your own delivery service. This will sh...      2       5
# 2  Add product recommendation blocks to the store...      8       3
# 3  Change the category structure. This will incre...      8       3
# 4  Change the background color on the main page. ...      3       1
# 5  Add a customer review page. This will increase...      3       2
# ...

# %% [markdown]
# **Comentarios:** Al cargar el dataframe se identifica que las columnas vienen unidas, por lo que se agrega el **sep =** y se cargan nuevamente para visualizar las columnas de manera adecuada. El tipo de columnas es correcto para realizar los próximos cálculos.

# %% [markdown]
# ### 1.2 - Priorización de hipótesis con framework ICE

# %%
hipotesis['ICE'] = (hipotesis['Impact'] * hipotesis['Confidence']) / hipotesis['Effort']

print(hipotesis[['Hypothesis', 'ICE']].sort_values(by='ICE', ascending = False))
# Out:
#                                           Hypothesis        ICE
# 8  Launch a promotion that gives users discounts ...  16.200000
# 0  Add two new channels for attracting traffic. T...  13.333333
# 7  Add a subscription form to all the main pages....  11.200000
# 6  Show banners with current offers and sales on ...   8.000000
# 2  Add product recommendation blocks to the store...   7.000000
# 1  Launch your own delivery service. This will sh...   2.000000
# 5  Add a customer review page. This will increase...   1.333333
# 3  Change the category structure. This will incre...   1.125000
# 4  Change the background color on the main page. ...   1.000000

# %% [markdown]
# ### 1.3 - Priorización de hipótesis con framework RICE

# %%
hipotesis['RICE'] = (hipotesis['Reach'] * hipotesis['Impact'] * hipotesis['Confidence']) / hipotesis['Effort']

print(hipotesis[['Hypothesis', 'RICE']].sort_values(by='RICE', ascending = False))
# Out:
#                                           Hypothesis   RICE
# 7  Add a subscription form to all the main pages....  112.0
# 2  Add product recommendation blocks to the store...   56.0
# 0  Add two new channels for attracting traffic. T...   40.0
# 6  Show banners with current offers and sales on ...   40.0
# 8  Launch a promotion that gives users discounts ...   16.2
# 3  Change the category structure. This will incre...    9.0
# 1  Launch your own delivery service. This will sh...    4.0
# 5  Add a customer review page. This will increase...    4.0
# 4  Change the background color on the main page. ...    3.0

# %% [markdown]
# ### 1.4 - Análisis; ¿Qué tanto cambia la priorización de hipótesis al utilizar RICE y ICE?

# %% [markdown]
# **Explicación:** La priorización cambia notoriamente, 7 de las 9 hipótesis cambian de lugar, sólo las hipótesis 6 y 4 se mantienen el mismo sitio. Por fórmula, el componente del alcance se encuentra en el numerador, lo cual se traduce como: A mayor alcance, mayor puntaje RICE (afectación de manera directamente proporcional).

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - Buena estructura en la Parte 1: corregiste el separador al cargar datos, calculaste ICE y RICE correctamente y comparaste con claridad el cambio de priorización, destacando el efecto del alcance en RICE. Avanzas con bases sólidas. </div>

# %% [markdown]
# ## Parte 2; Análisis de pruebas A/B

# %% [markdown]
# ### 2.1 - Carga y visualización de datos

# %% [markdown]
# #### 2.1.1 - Dataframe **orders**

# %%
orders = pd.read_csv('/datasets/orders_us.csv')
orders.info()
print()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   float64
#  4   group          1197 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 46.9+ KB
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     30.4     B
# 1     2804400009  3642806036  2019-08-15     15.2     B
# 2     2961555356  4069496402  2019-08-15     10.2     A
# 3     3797467345  1196621759  2019-08-15    155.1     B
# 4     2282983706  2322279887  2019-08-15     40.5     B

# %%
orders_column_names = {'transactionId':'transaction_id' , 'visitorId':'visitor_id'}
orders.rename(columns = orders_column_names, inplace = True)
orders['transaction_id'] = orders['transaction_id'].astype('str')
orders['visitor_id'] = orders['visitor_id'].astype('str')
orders['date'] = pd.to_datetime(orders['date'], format = '%Y-%m-%d')

# %%
orders.info()
print()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  1197 non-null   object
#  1   visitor_id      1197 non-null   object
#  2   date            1197 non-null   datetime64[ns]
#  3   revenue         1197 non-null   float64
#  4   group           1197 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 46.9+ KB
#   transaction_id  visitor_id       date  revenue group
# 0     3667963787  3312258926 2019-08-15     30.4     B
# 1     2804400009  3642806036 2019-08-15     15.2     B
# 2     2961555356  4069496402 2019-08-15     10.2     A
# 3     3797467345  1196621759 2019-08-15    155.1     B
# 4     2282983706  2322279887 2019-08-15     40.5     B

# %% [markdown]
# **Comentarios:** Para el dataframe **orders** se renombran dos columnas y se corrige el tipo de datos de 3 columnas.

# %% [markdown]
# #### 2.1.2 - Dataframe **visits**

# %%
visits = pd.read_csv('/datasets/visits_us.csv')
visits.info()
print()
visits.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    62 non-null     object
#  1   group   62 non-null     object
#  2   visits  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
#          date group  visits
# 0  2019-08-01     A     719
# 1  2019-08-02     A     619
# 2  2019-08-03     A     507
# 3  2019-08-04     A     717
# 4  2019-08-05     A     756

# %%
visits['date'] = pd.to_datetime(visits['date'], format = '%Y-%m-%d')
visits.info()
print()
visits.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    62 non-null     datetime64[ns]
#  1   group   62 non-null     object
#  2   visits  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB
#         date group  visits
# 0 2019-08-01     A     719
# 1 2019-08-02     A     619
# 2 2019-08-03     A     507
# 3 2019-08-04     A     717
# 4 2019-08-05     A     756

# %%
# IDs de visitantes únicos de cada grupo en 'orders'
visitors_groupA_orders = set(orders[orders['group'] == 'A']['visitor_id'])
visitors_groupB_orders = set(orders[orders['group'] == 'B']['visitor_id'])

# Encontrar la superposición de IDs de visitantes entre los dos grupos
intersected_visitors = visitors_groupA_orders.intersection(visitors_groupB_orders)

# Limpiar 'orders'
orders_clean = orders[~orders['visitor_id'].isin(intersected_visitors)]
orders_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  1016 non-null   object
#  1   visitor_id      1016 non-null   object
#  2   date            1016 non-null   datetime64[ns]
#  3   revenue         1016 non-null   float64
#  4   group           1016 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 47.6+ KB

# %% [markdown]
# **Comentarios:** El análisis de los resultados de las pruebas A/B tendrá un sesgo, dado que aunque se están eliminando los usuarios que se encuentran repetidos para ambos grupos (intersected_visitors) en el dataframe **orders**, estos no se pueden relacionar con el dataframe **visits** porque en este dataframe no se proporciona la columna visitor_id. Se continuará con el análisis en el supuesto de que se acepta tomar el riesgo del sesgo mencionado.

# %% [markdown]
# ### 2.2 - Analisis de pruebas A/B

# %% [markdown]
# #### 2.2.1 - Representa gráficamente el ingreso acumulado por grupo. Haz conclusiones y conjeturas.

# %%
ingresos_diarios = orders_clean.groupby(['date', 'group']).agg(ingreso_día=('revenue', 'sum')).reset_index()
ingreso_acumulado = ingresos_diarios.groupby('group').apply(lambda x: x.sort_values('date').assign(ingreso_acumulado=x['ingreso_día'].cumsum())).reset_index(drop=True)

# %%
plt.figure(figsize=(12, 4))

for group in ['A', 'B']:
    plt.plot(ingreso_acumulado[ingreso_acumulado['group'] == group]['date'],
             ingreso_acumulado[ingreso_acumulado['group'] == group]['ingreso_acumulado'],
             label=f'Grupo {group}')

plt.title('Ingreso Acumulado por Grupo')
plt.xlabel('Fecha')
plt.ylabel('Ingreso Acumulado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusiones:** En el gráfico se puede observar que para ambos grupos los ingresos se mantenían similares desde el inicio de la prueba hasta el día 17, sin embargo a partir del día 18 hubo un aumento significativo en los ingresos acumulados del grupo B, los cuales se mantuvieron hasta el final de la prueba.

# %% [markdown]
# #### 2.2.2 - Representa gráficamente el tamaño de pedido promedio acumulado por grupo. Haz conclusiones y conjeturas.

# %%
pedido_día = orders_clean.groupby(['date', 'group']).agg(pedidos=('transaction_id', 'count'),ingresos=('revenue', 'sum')).reset_index()
pedido_día = pedido_día.sort_values(by=['group', 'date'])

pedido_día['pedidos_acumulados'] = pedido_día.groupby('group')['pedidos'].cumsum()
pedido_día['ingresos_acumulados'] = pedido_día.groupby('group')['ingresos'].cumsum()

pedido_día['tamaño_pedido_promedio_acumulado'] = (pedido_día['ingresos_acumulados'] / pedido_día['pedidos_acumulados'])

# %%
plt.figure(figsize=(12, 4))

for group in ['A', 'B']:
    plt.plot(pedido_día[pedido_día['group'] == group]['date'],
             pedido_día[pedido_día['group'] == group]['tamaño_pedido_promedio_acumulado'],
             label=f'Grupo {group}')

plt.title('Tamaño de Pedido Promedio Acumulado por Grupo')
plt.xlabel('Fecha')
plt.ylabel('Tamaño de Pedido Promedio Acumulado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusión:** Hasta el día 17 el tamaño de pedido promedio se mantenía fluctuante para ambos grupos, a partir del día 18 hubo un aumento notorio para el grupo B, el tamaño de pedido promedio se mantuvo mayor en el grupo B hasta el final de la prueba.

# %% [markdown]
# #### 2.2.3 - Representa gráficamente la diferencia relativa en el tamaño de pedido promedio acumulado para el grupo B en comparación con el grupo A. Haz conclusiones y conjeturas.

# %%
pedido_día_pivot = pedido_día.pivot_table(index='date', columns='group', values='tamaño_pedido_promedio_acumulado').reset_index()
pedido_día_pivot['diferencia_relativa'] = ((pedido_día_pivot['B'] - pedido_día_pivot['A']) / pedido_día_pivot['A'])

# %%
plt.figure(figsize=(12, 6))

plt.plot(pedido_día_pivot['date'], pedido_día_pivot['diferencia_relativa'])

plt.axhline(y=0, color='red', linestyle='--')

plt.title('Dif. Relativa; Tamaño de Pedido Promedio Acumulado (Grupo B vs Grupo A)')
plt.xlabel('Fecha')
plt.ylabel('Diferencia Relativa')
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusión:** La diferencia relativa fue fluctuante hasta el día 17. No obstante, a partir del día 18 aumento positivamente y se mantuvo así hasta el final de la prueba.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - La representación y análisis de los gráficos es clara, mostrando bien las tendencias y diferencias entre grupos. Se aprecia consistencia en el enfoque y una interpretación precisa de los cambios a partir del día 18. </div>

# %% [markdown]
# #### 2.2.4 - Calcula la tasa de conversión de cada grupo como la relación entre los pedidos y el número de visitas de cada día. Representa gráficamente las tasas de conversión diarias de los dos grupos y describe la diferencia. Saca conclusiones y haz conjeturas.

# %%
pedidos_diarios = orders_clean.groupby(['date', 'group'])['transaction_id'].count().reset_index()

conversion_diaria = pd.merge(pedidos_diarios, visits, on=['date', 'group'], how='outer').fillna(0)

conversion_diaria['tasa_conversion'] = conversion_diaria['transaction_id'] / conversion_diaria['visits']

# %%
plt.figure(figsize=(14, 6))

plt.plot(conversion_diaria[conversion_diaria['group'] == 'A']['date'],
         conversion_diaria[conversion_diaria['group'] == 'A']['tasa_conversion'],
         label='Grupo A')

plt.plot(conversion_diaria[conversion_diaria['group'] == 'B']['date'],
         conversion_diaria[conversion_diaria['group'] == 'B']['tasa_conversion'],
         label='Grupo B')

plt.title('Tasa de Conversión Diaria por Grupo')
plt.xlabel('Fecha')
plt.ylabel('Tasa de Conversión')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusión:** Podemos observar que la tasa de conversión para el grupo B suele mostrar picos más anchos y/o altos que para el grupo A, lo cual puede traducirse como una mayor tasa de conversión diaria.

# %% [markdown]
# #### 2.2.5 - Traza un gráfico de dispersión del número de pedidos por usuario. Haz conclusiones y conjeturas.

# %%
pedidos_por_usuario = orders_clean.groupby('visitor_id')['transaction_id'].count().reset_index()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.scatter(x=pedidos_por_usuario.index, y=pedidos_por_usuario['transaction_id'])

plt.title('Gráfico de Dispersión del Número de Pedidos por Usuario')
plt.xlabel('Usuarios (índice)')
plt.ylabel('Número de Pedidos')
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusión:** La mayoría de los usuarios realizan una compra, después 2 y finalmente con menor frecuencia 3.

# %% [markdown]
# #### 2.2.6 - Calcula los percentiles 95 y 99 del número de pedidos por usuario. Define el punto en el cual un punto de datos se convierte en una anomalía.

# %%
percentiles_pedidos_usuario = np.percentile(pedidos_por_usuario['transaction_id'], [95, 99])

print("Percentiles del número de pedidos por usuario:")
print(percentiles_pedidos_usuario)
# Out:
# Percentiles del número de pedidos por usuario:
# [1. 2.]

# %% [markdown]
# **Interpretación:**
# - No más del 5% de los usuarios realizan más de un pedido.
# - No más del 1& de los usuarios realizan más de dos pedidos.

# %% [markdown]
# #### 2.2.7 - Traza un gráfico de dispersión de los precios de los pedidos. Haz conclusiones y conjeturas.

# %%
plt.figure(figsize=(12, 6))

plt.scatter(x=orders_clean.index, y=orders_clean['revenue'], alpha = 0.5)

plt.title('Gráfico de Dispersión de Precios de Pedidos')
plt.xlabel('Pedidos (índice)')
plt.ylabel('Precio del Pedido')
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusión:** La gran mayoría de los pedidos suelen tener precios por debajo de 1500.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - Los cálculos y visualizaciones están bien estructurados, con interpretaciones concisas y coherentes. Lograste identificar patrones clave en conversión, comportamiento de usuarios y precios de pedidos de forma clara y ordenada. </div>

# %% [markdown]
# #### 2.2.8 - Calcula los percentiles 95 y 99 de los precios de los pedidos. Define el punto en el cual un punto de datos se convierte en una anomalía.

# %%
percentiles_precios_pedidos = np.percentile(orders_clean['revenue'], [95, 99])

print("Percentiles de los precios de los pedidos:")
print(percentiles_precios_pedidos)
# Out:
# Percentiles de los precios de los pedidos:
# [414.275 830.3  ]

# %% [markdown]
# **Interpretación:**
# - No más del 5% de los pedidos cuestan más de 414.275
# - No más del 1% de los pedidos cuestan más de 830.3

# %% [markdown]
# #### 2.2.9 - Encuentra la significancia estadística de la diferencia en la conversión entre los grupos utilizando los datos en bruto. Haz conclusiones y conjeturas.

# %%
conversión_por_grupo = orders_clean.groupby('group')['visitor_id'].nunique()
visitas_por_grupo = visits.groupby('group')['visits'].sum()

# %%
# Extraer los datos para successes y trials
successes = [conversión_por_grupo['A'], conversión_por_grupo['B']]
trials = [visitas_por_grupo['A'], visitas_por_grupo['B']]

# Calcular proporción de éxito de cada grupo
p1 = successes[0] / trials[0]
p2 = successes[1] / trials[1]
difference = p2 - p1

# Calcular la proporción de éxito combinada
p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

# Calcula la estadística en desviaciones estándar de la distribución normal estándar
z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

# Establecer la distribución normal estándar (media 0, desviación estándar 1)
distr = st.norm(0, 1) 

# Calcular el valor p (prueba de dos colas)
p_value = (1 - distr.cdf(abs(z_value))) * 2

print(f"z_value: {z_value:.4f}")
print(f"p_value: {p_value:.4f}")

alpha = 0.05

if p_value < alpha:
    print("Rechazar la hipótesis nula: hay una diferencia significativa entre las proporciones.")
else:
    print("No se pudo rechazar la hipótesis nula: no hay razón para pensar que las proporciones son diferentes.")
# Out:
# z_value: 2.5449
# p_value: 0.0109
# Rechazar la hipótesis nula: hay una diferencia significativa entre las proporciones.

# %% [markdown]
# #### 2.2.10 - Encuentra la significancia estadística de la diferencia en el tamaño promedio de pedido entre los grupos utilizando los datos en bruto. Haz conclusiones y conjeturas.

# %%
ingresos_grupo_a = orders_clean[orders_clean['group'] == 'A']['revenue']
ingresos_grupo_b = orders_clean[orders_clean['group'] == 'B']['revenue']

alpha = 0.05
results = st.ttest_ind(ingresos_grupo_a, ingresos_grupo_b, equal_var=False)

print('valor p:', results.pvalue)

if p_value < alpha:
    print("\nConclusión: La diferencia en el tamaño promedio de pedido es estadísticamente significativa.")
else:
    print("\nConclusión: La diferencia en el tamaño promedio de pedido NO es estadísticamente significativa.")
# Out:
# valor p: 0.4043438730780975
#
# Conclusión: La diferencia en el tamaño promedio de pedido es estadísticamente significativa.

# %% [markdown]
# #### 2.2.11 - Encuentra la significancia estadística de la diferencia en la conversión entre los grupos utilizando los datos filtrados. Haz conclusiones y conjeturas.

# %%
pedidos_por_usuario_para_anomalías = orders_clean.groupby('visitor_id')['transaction_id'].count()
usuarios_anomalos = pedidos_por_usuario_para_anomalías[pedidos_por_usuario_para_anomalías > 2].index

umbral_precio = np.percentile(orders_clean['revenue'], 99)

orders_para_anomalías = orders_clean[~orders_clean['visitor_id'].isin(usuarios_anomalos)]
orders_para_anomalías = orders_para_anomalías[orders_para_anomalías['revenue'] <= umbral_precio]


# Contar el número de conversiones (éxitos) y visitas (intentos) por grupo
conversiones_por_grupo_filtrado = orders_para_anomalías.groupby('group')['visitor_id'].nunique()

# Extraer los datos para successes y trials
successes_filtrado = [conversiones_por_grupo_filtrado['A'], conversiones_por_grupo_filtrado['B']]
trials = [visitas_por_grupo['A'], visitas_por_grupo['B']]

# Calcular la proporción de éxito de cada grupo
p1_filtrado = successes_filtrado[0] / trials[0]
p2_filtrado = successes_filtrado[1] / trials[1]
difference_filtrado = p2_filtrado - p1_filtrado

# Calcular la proporción de éxito combinada
p_combined_filtrado = (successes_filtrado[0] + successes_filtrado[1]) / (trials[0] + trials[1])

# Calcular la estadística Z
z_value_filtrado = difference_filtrado / mth.sqrt(p_combined_filtrado * (1 - p_combined_filtrado) * (1/trials[0] + 1/trials[1]))

# Establecer la distribución normal estándar
distr = st.norm(0, 1) 

p_value_filtrado = (1 - distr.cdf(abs(z_value_filtrado))) * 2

print(f"z_value: {z_value_filtrado:.4f}")
print(f"p_value: {p_value_filtrado:.4f}")

alpha = 0.05
if p_value_filtrado < alpha:
    print("Rechazar la hipótesis nula: hay una diferencia significativa entre las proporciones.")
else:
    print("No se pudo rechazar la hipótesis nula: no hay razón para pensar que las proporciones son diferentes.")
# Out:
# z_value: 2.6990
# p_value: 0.0070
# Rechazar la hipótesis nula: hay una diferencia significativa entre las proporciones.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - Presentaste de forma ordenada los cálculos estadísticos, identificando correctamente las diferencias significativas en conversión, incluso tras filtrar anomalías. El análisis refleja un buen dominio de las pruebas y su interpretación. </div>

# %% [markdown]
# #### 2.2.12 - Encuentra la significancia estadística de la diferencia en el tamaño promedio de pedido entre los grupos utilizando los datos filtrados. Haz conclusiones y conjeturas.

# %%
# Crear un dataframe filtrado sin los valores atípicos
orders_filtrado_final = orders_clean[~orders_clean['visitor_id'].isin(usuarios_anomalos)]
orders_filtrado_final = orders_filtrado_final[orders_filtrado_final['revenue'] <= umbral_precio]

ingresos_grupo_a_filtrado = orders_filtrado_final[orders_filtrado_final['group'] == 'A']['revenue']
ingresos_grupo_b_filtrado = orders_filtrado_final[orders_filtrado_final['group'] == 'B']['revenue']

result_filtrado = st.ttest_ind(ingresos_grupo_a_filtrado, ingresos_grupo_b_filtrado, equal_var=False)

print('valor p:', result_filtrado.pvalue)

alpha = 0.05

if p_value < alpha:
    print("\nConclusión: La diferencia en el tamaño promedio de pedido es estadísticamente significativa.")
else:
    print("\nConclusión: La diferencia en el tamaño promedio de pedido NO es estadísticamente significativa.")
# Out:
# valor p: 0.7035214166868313
#
# Conclusión: La diferencia en el tamaño promedio de pedido es estadísticamente significativa.

# %% [markdown]
# #### 2.2.13 - Toma una decisión basada en los resultados de la prueba.
# Las decisiones posibles son:
# 1) Parar la prueba, considerar a uno de los grupos como líder.
# 2) Parar la prueba, concluir que no hay diferencia entre los grupos.
# 3) Continuar la prueba.

# %% [markdown]
# **Toma de decisión:** Considerando todos los resultados individuales del análisis, se recomienda parar la prueba y considerar el grupo B como líder, puesto que se observa que tiene la mayor cantidad de ingresos acumulados, tamaño de pedido y tasa de conversión.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - Cierre bien fundamentado: el filtrado, la prueba estadística y la decisión final se presentan de forma coherente, respaldando la elección del grupo B como líder con argumentos sólidos basados en métricas clave. </div>

# %% [markdown]
# ## Comentario general del revisor

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está **aprobado**. Has demostrado un excelente manejo de los datos, análisis exploratorio, y aplicación de pruebas estadísticas para la toma de decisiones. A continuación, destaco los puntos positivos:
#
# #### Puntos Positivos:
#
# * **Procesamiento de datos:** Correcta limpieza y preprocesamiento, identificando y tratando valores atípicos y datos duplicados para asegurar la calidad del análisis.
# * **Visualización y análisis gráfico:** Uso adecuado de gráficos para mostrar tendencias, diferencias y comportamientos entre grupos, con interpretaciones claras y relevantes.
# * **Ingeniería de métricas:** Cálculo preciso de indicadores clave como ICE, RICE, tasas de conversión y métricas acumuladas, aplicados de forma consistente para el análisis.
# * **Análisis estadístico:** Aplicación correcta de pruebas de significancia, interpretando con acierto los resultados y extrayendo conclusiones alineadas con los objetivos del proyecto.
#
# Tu trabajo evidencia un enfoque sólido y bien estructurado para respaldar decisiones basadas en datos.
